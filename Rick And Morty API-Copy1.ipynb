# %%
#Import Necessary Packages
import requests
import pandas as pd
#import Beautiful soup to help make sense of the html tags
from bs4 import BeautifulSoup
import re

# %%
#Pull all Characters into Df_Charactersrm
df_Charactersrm = pd.DataFrame()
for page in range(1,35):
    url='https://rickandmortyapi.com/api/character/?page=%s'%page
    response = requests.get(url)
    json_string = response.json()
    dftempchar = pd.json_normalize(json_string, record_path =['results'])
    df_Charactersrm = pd.concat([df_Charactersrm, dftempchar])

# %%
#Pull all Locations into Df_Locationsrm
df_Locationsrm = pd.DataFrame()
for page in range(1,7):
    url='https://rickandmortyapi.com/api/location/?page=%s'%page
    response = requests.get(url)
    json_string = response.json()
    dftemploc = pd.json_normalize(json_string, record_path =['results'])
    df_Locationsrm = pd.concat([df_Locationsrm, dftemploc])

# %%
#Pull all Episodes into Df_Episodesrm
df_Episodesrm = pd.DataFrame()
for page in range(1,4):
    url='https://rickandmortyapi.com/api/episode/?page=%s'%page
    response = requests.get(url)
    json_string = response.json()
    dftempep = pd.json_normalize(json_string, record_path =['results'])
    df_Episodesrm = pd.concat([df_Episodesrm, dftempep])

# %%
#Confirm Everything is There
print(df_Charactersrm.shape)
print(df_Locationsrm.shape)
print(df_Episodesrm.shape)
# Out:
# (671, 14)
# (108, 7)
# (41, 7)

# %%
#Now we will want to duplicate rows in the df_Charactersrm so that we have 1 row for each episode the character appeared in
df_Charactersrm =df_Charactersrm.explode('episode').reset_index(drop=True)
cols = list(df_Charactersrm.columns)
cols.append(cols.pop(cols.index('name')))
df_Charactersrm =df_Charactersrm[cols]

# %%
df_Charactersrm.shape
# Out:
# (1038, 14)

# %%
#Lets Do Some DF Cleanup pre Join

#Drop Unecessary Columns
df_Charactersrm = df_Charactersrm.drop(columns=['created','location.url','url','origin.url'])
df_Locationsrm = df_Locationsrm.drop(columns=['id','created','residents','url'])
df_Episodesrm = df_Episodesrm.drop(columns=['id','created','characters'])

#Rename Columns
df_Charactersrm = df_Charactersrm.rename(columns={"status":"Character_Status","species":"Character_Species","type":"Character_type","image":"Character_image","episode":"Episode_URL","origin.name":"Origin_Location_Name","location.name":"Current_Location_Name","name":"Character_Name"})
df_Episodesrm = df_Episodesrm.rename(columns={"url":"Episode_URL","name":"episode_name","episode":"episode_Number"})
#Rename Columns and Make 2 dfs for Location one for each join
df_Locationsrm_Current = df_Locationsrm.rename(columns={"name":"Current_Location_Name","type":"Current_Location_type","dimension":"Current Dimension"})
df_Locationsrm_Origin = df_Locationsrm.rename(columns={"name":"Origin_Location_Name","type":"Origin_Location_type","dimension":"Origin Dimension"})

# %%
#Join df_Charactersrm with df_Episodesrm to get episode information for each character
df_rm = df_Charactersrm.merge(df_Episodesrm, on='Episode_URL', how='left')
print(df_rm.shape)
#Join df_rm with df_Locationsrm_Current to get current location information
df_rm = df_rm.merge(df_Locationsrm_Current, on='Current_Location_Name', how='left')
print(df_rm.shape)
#Join df_rm with df_Locationsrm_Origin to get Origin location information
df_rm = df_rm.merge(df_Locationsrm_Origin, on='Origin_Location_Name', how='left')
print(df_rm.shape)
# Out:
# (1038, 13)
# (1038, 15)
# (1038, 17)

# %%
df_rm =df_rm.drop(columns=['Episode_URL'])

# %%
#Retrieve the HTMl data from the site and store in an object
URL = 'https://www.imdb.com/list/ls022236589/'
page = requests.get(URL)
#Apply Beautiful soup html parser 
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#Pull the specific element you need
results = soup.find(id='main')

# %%
# Leveage <section> element with the class card-content. to select only the job listings
Rick_elems = results.find_all('div', class_='lister-item-content')

# %%
#Now lets pull the descriptive class names
for Rick_elem in Rick_elems:
    RunTime_elem = Rick_elem.find('span', class_='runtime')
    Rank_elem = Rick_elem.find('span', class_='lister-item-index unbold text-primary')
    Rating_elem = Rick_elem.find('span', class_='ipl-rating-star__rating')
    Description_elem = Rick_elem.find('p', class_='')
    Title_elem = Rick_elem.select_one("a:nth-of-type(2)")
    print(RunTime_elem.text.strip())
    print(Rank_elem.text.strip())
    print(Rating_elem.text.strip())
    print(Description_elem.text.strip())
    print(Title_elem.text.strip())
    print()
# Out:
# 22 min
# 1.
# 9.6
# The Smith house is locked down after parasites threaten to take over the world by multiplying through flashbacks.
# Total Rickall
#
# 23 min
# 2.
# 9.3
# Rick turns himself into a pickle while Beth, Summer, and Morty go to family therapy.
# Pickle Rick
#
# 23 min
# 3.
# 8.9
# Rick and Morty try to save a gas life form while Jerry resides in a daycare made for Jerrys.
# Mortynight Run
#
# 22 min
# 4.
# 9.5
# Rick & Morty go on a simple exchange as Rick tells Morty if something goes wrong jump into the same vat of acid as he does.
# The Vat of Acid Episode
#
# 22 min
# 5.
# 9.6
# Rick, still in galactic prison, puts an intricate escape plan into action. Back on Earth, which is now under federation control, Morty and Summer have an argument about their grandpa.
# The Rickshank Rickdemption
#
# 22 min
# 6.
# 9.1
# After Rick gives Morty a love potion for a school dance, things quickly spiral out of control when the serum splices with the flu - causing it to spread. Rick and Morty scramble to cure the crisis, making matters worse in the process.
# Rick Potion #9
#
# 22 min
# 7.
# 8.9
# Following a stressful adventure, Rick and Morty go on a break to a spa where they remove their toxins, which in turn take a form of their own.
# Rest and Ricklaxation
#
# 22 min
# 8.
# 9.2
# An adventure with an invisibility belt, but a family that disappears together, must stay together.
# Star Mort Rickturn of the Jerri
#
# 22 min
# 9.
# 8.9
# Rick reveals to Morty his "Morty's mind blowers," a collection of memories Morty asked Rick to erase from his mind.
# Morty's Mind Blowers
#
# 22 min
# 10.
# 9.8
# Whilst Rick and Morty go off to adventure in Atlantis, we take a look at how the Citadel has rebuilt itself since both Rick and Morty visited.
# The Ricklantis Mixup
#
# 22 min
# 11.
# 8.8
# Rick helps Jerry out with the dog.
# Lawnmower Dog
#
# 23 min
# 12.
# 9.4
# Rick, falsely blamed for Murder by the council of Ricks, begins a cross-dimensional pursuit with the authorities while attempting to prove his innocence.
# Close Rick-counters of the Rick Kind
#
# 22 min
# 13.
# 9
# Rick brings Morty to a planet containing crystals that show whoever is touching them all the ways they may die depending on their choices.
# Edge of Tomorty: Rick Die Rickpeat
#
# 22 min
# 14.
# 8.9
# Morty discovers a race of intelligent space snakes after suffering a potentially lethal bite. Jerry attempts to prove that he isn't completely incompetent.
# Rattlestar Ricklactica
#
# 23 min
# 15.
# 8.6
# Rick gets emotional. Beth and Jerry get into a fight.
# Auto Erotic Assimilation
#
# 23 min
# 16.
# 9.4
# The Smith family is invited to the wedding of Rick's best friend, Birdperson. Things go south when it's discovered that the bride isn't who she says she is.
# The Wedding Squanchers
#
# 23 min
# 17.
# 8.8
# Rick hooks up the family's TV with interdimensional cable, allowing them to watch infinite TV from across the multiverse.
# Rixty Minutes
#
# 22 min
# 18.
# 8.7
# Rick and Morty try to get to the bottom of a mystery.
# M. Night Shaym-Aliens!
#
# 23 min
# 19.
# 9.3
# Rick is having trouble with his car and they have to fix it by traveling to the microverse.
# The Ricks Must Be Crazy
#
# 22 min
# 20.
# 8.4
# On a treasure-seeking expedition in an alien temple, Rick and Morty discover that a heist expert has snatched the prize from under their noses. Further twists, turns and double-crosses abound.
# One Crew over the Crewcoo's Morty
#
# 23 min
# 21.
# 8.6
# Rick and Morty arrive on an alien planet to fix their ship just as the day of the purge begins there, Jerry and Summer work on their father-daughter relationship, but his lack of employment keeps coming up.
# Look Who's Purging Now
#
# 23 min
# 22.
# 8.5
# Summer gets a job at a pawn shop owned by the devil. Jerry helps Morty with his science fair project.
# Something Ricked This Way Comes
#
# 22 min
# 23.
# 8.5
# Rick takes Jerry on a sympathy adventure to a resort where everyone is immortal when there, and Jerry meets some old acquaintances of Rick's who want payback.
# The Whirly Dirly Conspiracy
#
# 22 min
# 24.
# 9
# Rick provides the family with a solution to their problems, freeing him up to go on an adventure led by Morty.
# Meeseeks and Destroy
#
# 22 min
# 25.
# 8.3
# Rick goes to his private bathroom to find that someone else has used it. Jerry creates an app with an unlikely alien and Morty pays the price.
# The Old Man and the Seat
#
# 23 min
# 26.
# 8.5
# Beth and Jerry head for an iceberg of a date leaving Rick in charge. Morty doesn't get to go on any more adventures if the house isn't in the same condition when they get back.
# Ricksy Business
#
# 22 min
# 27.
# 8.4
# It's Christmas. Rick shrinks Morty, injecting him into a homeless man to save Anatomy Park. Jerry tries to have a Christmas free of electronic devices, but regrets his decision when his parents introduce him to their new friend.
# Anatomy Park
#
# 23 min
# 28.
# 8.9
# Having restarted time, Rick, Morty and Summer are in a quantum-uncertain state of existence. An argument leads to the creation of two alternate timelines, which need to be stitched back together fast if they are to escape quantum collapse.
# A Rickle in Time
#
# 23 min
# 29.
# 8.5
# Rick joins in on some hijinks by transferring his consciousness into teenage "Tiny Rick." Beth and Jerry sort out their relationship.
# Big Trouble in Little Sanchez
#
# 21 min
# 30.
# 8.1
# Rick, Morty and Summer visit an alien civilisation, where Rick and Morty are controlled by parasites and Summer lives a luxurious lifestyle.
# Promortyus
#
# 21 min
# 31.
# 8.1
# An anthology episode that follows Rick and Morty on a train with people who don't like Rick. They have to find their way out but they bump into unexpected situations along the way.
# Never Ricking Morty
#
# 22 min
# 32.
# 8
# A strangely eccentric genius scientist and inventor, moves into the home of his daughter and her family and begins to strongly influence his young grandson.
# Pilot
#
# 24 min
# 33.
# 8.3
# Rick and morty must aid Earth after a giant head disrupts the planet, demanding to see a hit song performed.
# Get Schwifty
#
# 22 min
# 34.
# 8
# Rick brings Beth to a world he created for her when she was younger while Beth looks for a long-lost childhood friend trapped there for years.
# The ABCs of Beth
#
# 22 min
# 35.
# 8.2
# With the kids dealing with their parents' divorce, Rick takes them to a Mad Max-style universe where he tries to steal a green crystal from a group of scavengers.
# Rickmancing the Stone
#
# 22 min
# 36.
# 8.2
# Rick and Morty are called upon by the president to kill a vicious alien in the secret tunnels under the White House.
# The Rickchurian Mortydate
#
# 22 min
# 37.
# 7.8
# Rick, Morty, Beth, Summer and Jerry share a galactic adventure.
# Childrick of Mort
#
# 23 min
# 38.
# 8
# Morty becomes a father to an alien baby, while Rick and Summer get trapped in a dangerous dimension.
# Raising Gazorpazorp
#
# 23 min
# 39.
# 7.7
# Jerry is faced with the difficult decision of losing his manhood in order to save an alien leader from imminent death. Meanwhile, Rick, Morty and Summer explore the possibilities of interdimensional television.
# Interdimensional Cable 2: Tempting Fate
#
# 23 min
# 40.
# 8.2
# Rick and Morty are summoned by the Vindicators to stop Worldender but end up in a deathtrap conceived by Drunk Rick.
# Vindicators 3: The Return of Worldender
#
# 22 min
# 41.
# 7.4
# Morty asks Rick for a dragon and Rick finds a wizard of another dimension who makes a soul bonding contract between Morty and a dragon called Balthromaw. Meanwhile, Jerry meets a talking cat in his bedroom who wants to fly to Florida.
# Claw and Hoarder: Special Ricktim's Morty

# %%
#Now lets turn this into a dataframe so we can use it for analysis
df_IMDB =[]
for Rick_elem in Rick_elems:
    RunTime_elem = Rick_elem.find('span', class_='runtime')
    Rank_elem = Rick_elem.find('span', class_='lister-item-index unbold text-primary')
    Rating_elem = Rick_elem.find('span', class_='ipl-rating-star__rating')
    Description_elem = Rick_elem.find('p', class_='')
    Title_elem = Rick_elem.select_one("a:nth-of-type(2)")
    if None in (RunTime_elem, Rank_elem, Rating_elem, Description_elem, Title_elem):
        continue
    Run_Time =RunTime_elem.text.strip()
    IMDB_Rank =Rank_elem.text.strip()
    IMDB_Rating =Rating_elem.text.strip()
    IMDB_Description = Description_elem.text.strip()
    IMDB_Episode_Title = Title_elem.text.strip()
    df_IMDB.append({'Run_Time' :Run_Time, 'IMDB_Rank' :IMDB_Rank, 'IMDB_Rating' :IMDB_Rating, 'IMDB_Description' :IMDB_Description, 'episode_name' :IMDB_Episode_Title})
pd.DataFrame(df_IMDB)
# Out:
#    Run_Time IMDB_Rank IMDB_Rating  \
# 0    22 min        1.         9.6
# 1    23 min        2.         9.3
# 2    23 min        3.         8.9
# 3    22 min        4.         9.5
# 4    22 min        5.         9.6
# 5    22 min        6.         9.1
# 6    22 min        7.         8.9
# 7    22 min        8.         9.2
# 8    22 min        9.         8.9
# 9    22 min       10.         9.8
# 10   22 min       11.         8.8
# 11   23 min       12.         9.4
# 12   22 min       13.           9
# 13   22 min       14.         8.9
# 14   23 min       15.         8.6
# 15   23 min       16.         9.4
# 16   23 min       17.         8.8
# 17   22 min       18.         8.7
# 18   23 min       19.         9.3
# 19   22 min       20.         8.4
# 20   23 min       21.         8.6
# 21   23 min       22.         8.5
# 22   22 min       23.         8.5
# 23   22 min       24.           9
# 24   22 min       25.         8.3
# 25   23 min       26.         8.5
# 26   22 min       27.         8.4
# 27   23 min       28.         8.9
# 28   23 min       29.         8.5
# 29   21 min       30.         8.1
# 30   21 min       31.         8.1
# 31   22 min       32.           8
# 32   24 min       33.         8.3
# 33   22 min       34.           8
# 34   22 min       35.         8.2
# 35   22 min       36.         8.2
# 36   22 min       37.         7.8
# 37   23 min       38.           8
# 38   23 min       39.         7.7
# 39   23 min       40.         8.2
# 40   22 min       41.         7.4
#
#                                      IMDB_Description  \
# 0   The Smith house is locked down after parasites...
# 1   Rick turns himself into a pickle while Beth, S...
# 2   Rick and Morty try to save a gas life form whi...
# 3   Rick & Morty go on a simple exchange as Rick t...
# 4   Rick, still in galactic prison, puts an intric...
# 5   After Rick gives Morty a love potion for a sch...
# 6   Following a stressful adventure, Rick and Mort...
# 7   An adventure with an invisibility belt, but a ...
# 8   Rick reveals to Morty his "Morty's mind blower...
# 9   Whilst Rick and Morty go off to adventure in A...
# 10                 Rick helps Jerry out with the dog.
# 11  Rick, falsely blamed for Murder by the council...
# 12  Rick brings Morty to a planet containing cryst...
# 13  Morty discovers a race of intelligent space sn...
# 14  Rick gets emotional. Beth and Jerry get into a...
# 15  The Smith family is invited to the wedding of ...
# 16  Rick hooks up the family's TV with interdimens...
# 17  Rick and Morty try to get to the bottom of a m...
# 18  Rick is having trouble with his car and they h...
# 19  On a treasure-seeking expedition in an alien t...
# 20  Rick and Morty arrive on an alien planet to fi...
# 21  Summer gets a job at a pawn shop owned by the ...
# 22  Rick takes Jerry on a sympathy adventure to a ...
# 23  Rick provides the family with a solution to th...
# 24  Rick goes to his private bathroom to find that...
# 25  Beth and Jerry head for an iceberg of a date l...
# 26  It's Christmas. Rick shrinks Morty, injecting ...
# 27  Having restarted time, Rick, Morty and Summer ...
# 28  Rick joins in on some hijinks by transferring ...
# 29  Rick, Morty and Summer visit an alien civilisa...
# 30  An anthology episode that follows Rick and Mor...
# 31  A strangely eccentric genius scientist and inv...
# 32  Rick and morty must aid Earth after a giant he...
# 33  Rick brings Beth to a world he created for her...
# 34  With the kids dealing with their parents' divo...
# 35  Rick and Morty are called upon by the presiden...
# 36  Rick, Morty, Beth, Summer and Jerry share a ga...
# 37  Morty becomes a father to an alien baby, while...
# 38  Jerry is faced with the difficult decision of ...
# 39  Rick and Morty are summoned by the Vindicators...
# 40  Morty asks Rick for a dragon and Rick finds a ...
#
#                                  episode_name
# 0                               Total Rickall
# 1                                 Pickle Rick
# 2                              Mortynight Run
# 3                     The Vat of Acid Episode
# 4                  The Rickshank Rickdemption
# 5                              Rick Potion #9
# 6                       Rest and Ricklaxation
# 7             Star Mort Rickturn of the Jerri
# 8                        Morty's Mind Blowers
# 9                        The Ricklantis Mixup
# 10                              Lawnmower Dog
# 11       Close Rick-counters of the Rick Kind
# 12         Edge of Tomorty: Rick Die Rickpeat
# 13                     Rattlestar Ricklactica
# 14                   Auto Erotic Assimilation
# 15                     The Wedding Squanchers
# 16                              Rixty Minutes
# 17                     M. Night Shaym-Aliens!
# 18                    The Ricks Must Be Crazy
# 19          One Crew over the Crewcoo's Morty
# 20                     Look Who's Purging Now
# 21            Something Ricked This Way Comes
# 22                The Whirly Dirly Conspiracy
# 23                       Meeseeks and Destroy
# 24                   The Old Man and the Seat
# 25                            Ricksy Business
# 26                               Anatomy Park
# 27                           A Rickle in Time
# 28              Big Trouble in Little Sanchez
# 29                                 Promortyus
# 30                        Never Ricking Morty
# 31                                      Pilot
# 32                               Get Schwifty
# 33                           The ABCs of Beth
# 34                      Rickmancing the Stone
# 35                  The Rickchurian Mortydate
# 36                          Childrick of Mort
# 37                        Raising Gazorpazorp
# 38    Interdimensional Cable 2: Tempting Fate
# 39    Vindicators 3: The Return of Worldender
# 40  Claw and Hoarder: Special Ricktim's Morty

# %%
#Now we need to join our df_rm which is our data from the Rick and Morty API with the data we just pulled from IMDB on Rick and Morty
#lets make df_IMDB into a dataframe 
df_IMDB = pd.DataFrame(df_IMDB)

#Before Joining since the episode names arent exactly the same and we don't have a unique identifier we will do a few fixes
df_rm['episode_name'] = df_rm['episode_name'].str.replace("'", "")
df_rm['episode_name'] = df_rm['episode_name'].str.replace(":", "")
df_rm['episode_name'] = df_rm['episode_name'].str.replace(",", "")

df_IMDB['episode_name'] =df_IMDB['episode_name'].str.replace("'","")
df_IMDB['episode_name'] =df_IMDB['episode_name'].str.replace(":","")
df_IMDB['episode_name'] =df_IMDB['episode_name'].str.replace(",","")

df_rm['episode_name'] = df_rm['episode_name'].str.title()
df_IMDB['episode_name'] =df_IMDB['episode_name'].str.title()
#Join df_rm with df_IMDB to get the information from IMDB into the rest of our table
df_rm = df_rm.merge(df_IMDB, on='episode_name', how='left')
df_rm
# Out:
#        id Character_Status Character_Species Character_type  gender  \
# 0       1            Alive             Human                   Male
# 1       1            Alive             Human                   Male
# 2       1            Alive             Human                   Male
# 3       1            Alive             Human                   Male
# 4       1            Alive             Human                   Male
# ...   ...              ...               ...            ...     ...
# 1033  667            Alive             Human                 Female
# 1034  668            Alive             Alien     Cat-Person  Female
# 1035  669            Alive             Alien                   Male
# 1036  670             Dead             Alien    Gromflomite    Male
# 1037  671             Dead             Alien    Gromflomite    Male
#
#                                         Character_image  \
# 0     https://rickandmortyapi.com/api/character/avat...
# 1     https://rickandmortyapi.com/api/character/avat...
# 2     https://rickandmortyapi.com/api/character/avat...
# 3     https://rickandmortyapi.com/api/character/avat...
# 4     https://rickandmortyapi.com/api/character/avat...
# ...                                                 ...
# 1033  https://rickandmortyapi.com/api/character/avat...
# 1034  https://rickandmortyapi.com/api/character/avat...
# 1035  https://rickandmortyapi.com/api/character/avat...
# 1036  https://rickandmortyapi.com/api/character/avat...
# 1037  https://rickandmortyapi.com/api/character/avat...
#
#                Origin_Location_Name          Current_Location_Name  \
# 0                     Earth (C-137)  Earth (Replacement Dimension)
# 1                     Earth (C-137)  Earth (Replacement Dimension)
# 2                     Earth (C-137)  Earth (Replacement Dimension)
# 3                     Earth (C-137)  Earth (Replacement Dimension)
# 4                     Earth (C-137)  Earth (Replacement Dimension)
# ...                             ...                            ...
# 1033  Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 1034                 Planet Squanch                Defiance's Ship
# 1035                        unknown                Defiance's Base
# 1036                 Gromflom Prime            NX-5 Planet Remover
# 1037                 Gromflom Prime            NX-5 Planet Remover
#
#                               Character_Name                     episode_name  \
# 0                               Rick Sanchez                            Pilot
# 1                               Rick Sanchez                    Lawnmower Dog
# 2                               Rick Sanchez                     Anatomy Park
# 3                               Rick Sanchez           M. Night Shaym-Aliens!
# 4                               Rick Sanchez             Meeseeks And Destroy
# ...                                      ...                              ...
# 1033                           Defiance Beth  Star Mort Rickturn Of The Jerri
# 1034                    Defiance Squanchette  Star Mort Rickturn Of The Jerri
# 1035                         Defiance Doctor  Star Mort Rickturn Of The Jerri
# 1036  New Improved Galactic Federation Guard  Star Mort Rickturn Of The Jerri
# 1037  New Improved Galactic Federation Guard  Star Mort Rickturn Of The Jerri
#
#                air_date episode_Number Current_Location_type  \
# 0      December 2, 2013         S01E01                Planet
# 1      December 9, 2013         S01E02                Planet
# 2     December 16, 2013         S01E03                Planet
# 3      January 13, 2014         S01E04                Planet
# 4      January 20, 2014         S01E05                Planet
# ...                 ...            ...                   ...
# 1033       May 31, 2020         S04E10                Planet
# 1034       May 31, 2020         S04E10            Spacecraft
# 1035       May 31, 2020         S04E10                  Base
# 1036       May 31, 2020         S04E10            Death Star
# 1037       May 31, 2020         S04E10            Death Star
#
#           Current Dimension Origin_Location_type       Origin Dimension  \
# 0     Replacement Dimension               Planet        Dimension C-137
# 1     Replacement Dimension               Planet        Dimension C-137
# 2     Replacement Dimension               Planet        Dimension C-137
# 3     Replacement Dimension               Planet        Dimension C-137
# 4     Replacement Dimension               Planet        Dimension C-137
# ...                     ...                  ...                    ...
# 1033  Replacement Dimension               Planet  Replacement Dimension
# 1034  Replacement Dimension               Planet  Replacement Dimension
# 1035  Replacement Dimension                  NaN                    NaN
# 1036  Replacement Dimension               Planet  Replacement Dimension
# 1037  Replacement Dimension               Planet  Replacement Dimension
#
#      Run_Time IMDB_Rank IMDB_Rating  \
# 0      22 min       32.           8
# 1      22 min       11.         8.8
# 2      22 min       27.         8.4
# 3      22 min       18.         8.7
# 4      22 min       24.           9
# ...       ...       ...         ...
# 1033   22 min        8.         9.2
# 1034   22 min        8.         9.2
# 1035   22 min        8.         9.2
# 1036   22 min        8.         9.2
# 1037   22 min        8.         9.2
#
#                                        IMDB_Description
# 0     A strangely eccentric genius scientist and inv...
# 1                    Rick helps Jerry out with the dog.
# 2     It's Christmas. Rick shrinks Morty, injecting ...
# 3     Rick and Morty try to get to the bottom of a m...
# 4     Rick provides the family with a solution to th...
# ...                                                 ...
# 1033  An adventure with an invisibility belt, but a ...
# 1034  An adventure with an invisibility belt, but a ...
# 1035  An adventure with an invisibility belt, but a ...
# 1036  An adventure with an invisibility belt, but a ...
# 1037  An adventure with an invisibility belt, but a ...
#
# [1038 rows x 20 columns]

# %%
df_rm.to_csv('Rick_And_Morty_Combined.csv')

# %%
df_IMDB
# Out:
#    Run_Time IMDB_Rank IMDB_Rating  \
# 0    22 min        1.         9.6
# 1    23 min        2.         9.3
# 2    23 min        3.         8.9
# 3    22 min        4.         9.5
# 4    22 min        5.         9.6
# 5    22 min        6.         9.1
# 6    22 min        7.         8.9
# 7    22 min        8.         9.2
# 8    22 min        9.         8.9
# 9    22 min       10.         9.8
# 10   22 min       11.         8.8
# 11   23 min       12.         9.4
# 12   22 min       13.           9
# 13   22 min       14.         8.9
# 14   23 min       15.         8.6
# 15   23 min       16.         9.4
# 16   23 min       17.         8.8
# 17   22 min       18.         8.7
# 18   23 min       19.         9.3
# 19   22 min       20.         8.4
# 20   23 min       21.         8.6
# 21   23 min       22.         8.5
# 22   22 min       23.         8.5
# 23   22 min       24.           9
# 24   22 min       25.         8.3
# 25   23 min       26.         8.5
# 26   22 min       27.         8.4
# 27   23 min       28.         8.9
# 28   23 min       29.         8.5
# 29   21 min       30.         8.1
# 30   21 min       31.         8.1
# 31   22 min       32.           8
# 32   24 min       33.         8.3
# 33   22 min       34.           8
# 34   22 min       35.         8.2
# 35   22 min       36.         8.2
# 36   22 min       37.         7.8
# 37   23 min       38.           8
# 38   23 min       39.         7.7
# 39   23 min       40.         8.2
# 40   22 min       41.         7.4
#
#                                      IMDB_Description  \
# 0   The Smith house is locked down after parasites...
# 1   Rick turns himself into a pickle while Beth, S...
# 2   Rick and Morty try to save a gas life form whi...
# 3   Rick & Morty go on a simple exchange as Rick t...
# 4   Rick, still in galactic prison, puts an intric...
# 5   After Rick gives Morty a love potion for a sch...
# 6   Following a stressful adventure, Rick and Mort...
# 7   An adventure with an invisibility belt, but a ...
# 8   Rick reveals to Morty his "Morty's mind blower...
# 9   Whilst Rick and Morty go off to adventure in A...
# 10                 Rick helps Jerry out with the dog.
# 11  Rick, falsely blamed for Murder by the council...
# 12  Rick brings Morty to a planet containing cryst...
# 13  Morty discovers a race of intelligent space sn...
# 14  Rick gets emotional. Beth and Jerry get into a...
# 15  The Smith family is invited to the wedding of ...
# 16  Rick hooks up the family's TV with interdimens...
# 17  Rick and Morty try to get to the bottom of a m...
# 18  Rick is having trouble with his car and they h...
# 19  On a treasure-seeking expedition in an alien t...
# 20  Rick and Morty arrive on an alien planet to fi...
# 21  Summer gets a job at a pawn shop owned by the ...
# 22  Rick takes Jerry on a sympathy adventure to a ...
# 23  Rick provides the family with a solution to th...
# 24  Rick goes to his private bathroom to find that...
# 25  Beth and Jerry head for an iceberg of a date l...
# 26  It's Christmas. Rick shrinks Morty, injecting ...
# 27  Having restarted time, Rick, Morty and Summer ...
# 28  Rick joins in on some hijinks by transferring ...
# 29  Rick, Morty and Summer visit an alien civilisa...
# 30  An anthology episode that follows Rick and Mor...
# 31  A strangely eccentric genius scientist and inv...
# 32  Rick and morty must aid Earth after a giant he...
# 33  Rick brings Beth to a world he created for her...
# 34  With the kids dealing with their parents' divo...
# 35  Rick and Morty are called upon by the presiden...
# 36  Rick, Morty, Beth, Summer and Jerry share a ga...
# 37  Morty becomes a father to an alien baby, while...
# 38  Jerry is faced with the difficult decision of ...
# 39  Rick and Morty are summoned by the Vindicators...
# 40  Morty asks Rick for a dragon and Rick finds a ...
#
#                                episode_name
# 0                             Total Rickall
# 1                               Pickle Rick
# 2                            Mortynight Run
# 3                   The Vat Of Acid Episode
# 4                The Rickshank Rickdemption
# 5                            Rick Potion #9
# 6                     Rest And Ricklaxation
# 7           Star Mort Rickturn Of The Jerri
# 8                       Mortys Mind Blowers
# 9                      The Ricklantis Mixup
# 10                            Lawnmower Dog
# 11     Close Rick-Counters Of The Rick Kind
# 12        Edge Of Tomorty Rick Die Rickpeat
# 13                   Rattlestar Ricklactica
# 14                 Auto Erotic Assimilation
# 15                   The Wedding Squanchers
# 16                            Rixty Minutes
# 17                   M. Night Shaym-Aliens!
# 18                  The Ricks Must Be Crazy
# 19         One Crew Over The Crewcoos Morty
# 20                    Look Whos Purging Now
# 21          Something Ricked This Way Comes
# 22              The Whirly Dirly Conspiracy
# 23                     Meeseeks And Destroy
# 24                 The Old Man And The Seat
# 25                          Ricksy Business
# 26                             Anatomy Park
# 27                         A Rickle In Time
# 28            Big Trouble In Little Sanchez
# 29                               Promortyus
# 30                      Never Ricking Morty
# 31                                    Pilot
# 32                             Get Schwifty
# 33                         The Abcs Of Beth
# 34                    Rickmancing The Stone
# 35                The Rickchurian Mortydate
# 36                        Childrick Of Mort
# 37                      Raising Gazorpazorp
# 38   Interdimensional Cable 2 Tempting Fate
# 39   Vindicators 3 The Return Of Worldender
# 40  Claw And Hoarder Special Ricktims Morty
